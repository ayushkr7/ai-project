# %%
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# !pip install Spotipy 
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: Spotipy in /usr/local/lib/python3.7/dist-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from Spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from Spotipy) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from Spotipy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->Spotipy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->Spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->Spotipy) (2021.10.8)

# %%
pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.7/dist-packages (0.1.22)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.26.9)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.0.12)

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/datasets/yamaerenay/spotify-dataset-19212020-600k-tracks'
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in "./spotify-dataset-19212020-600k-tracks" (use force=True to force download)

# %%
data_dir = './spotify-dataset-19212020-600k-tracks'

# %%
import os
os.listdir(data_dir)
# Out:
# ['artists.csv', 'data.csv', 'tracks.csv', 'dict_artists.json']

# %%
dataset = pd.read_csv(data_dir + '/data.csv')

# %%
df = dataset.select_dtypes(np.number)
number_cols = list(df.columns)

# %% [markdown]
# ## Standard Scaler
# Before Clustering our data we need to scale down the features to to a given range so that the clustering algorithm dosen't favour a particular feature just because it has a greater value
#
# we will be using Standard Scaler from the sci-kit learn library to scale down our data.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaled_X = scaler.fit_transform(df.values)

scaled_df = pd.DataFrame(scaled_X,
columns=df.columns)

# %% [markdown]
# ## PCA
# Linear dimensionality reduction using Singular Value Decomposition of the data to project it to a lower dimensional space. The input data is centered but not scaled for each feature before applying the SVD.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

pca.fit(scaled_df)

pca_df = pca.transform(scaled_df)

# %%
# importing metric library
from sklearn import metrics

# %% [markdown]
# ## Kmeans Clustering
# K-Means clustering is an unsupervised learning algorithm, which is used when you have unlabeled data. The aim of this algorithm is to find groups in the data. K-means clustering algorithm has many uses for grouping text documents, images, videos, and much more. It works iteratively to assign each data point to one of the groups based on the Euclidean distance.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8, verbose=2)

# %%
kmeans.fit(pca_df)
# Out:
# Initialization complete
# Iteration 0, inertia 162711.45838506133
# Iteration 1, inertia 153267.60945333185
# Iteration 2, inertia 147808.12935921672
# Iteration 3, inertia 144471.84023881017
# Iteration 4, inertia 142642.24264643755
# Iteration 5, inertia 141579.51845790114
# Iteration 6, inertia 140858.2289886051
# Iteration 7, inertia 140285.6106319623
# Iteration 8, inertia 139849.62602773885
# Iteration 9, inertia 139510.12658809702
# Iteration 10, inertia 139233.0706734676
# Iteration 11, inertia 138983.94187230448
# Iteration 12, inertia 138774.14103733306
# Iteration 13, inertia 138603.09488472622
# Iteration 14, inertia 138459.38875163664
# Iteration 15, inertia 138338.25458568404
# Iteration 16, inertia 138244.57613943116
# Iteration 17, inertia 138175.4883693821
# Iteration 18, inertia 138120.9938910728
# Iteration 19, inertia 138074.49774563347
# Iteration 20, inertia 138037.99297306206
# Iteration 21, inertia 138006.2987663648
# Iteration 22, inertia 137978.61266895544
# Iteration 23, inertia 137957.1271989558
# Iteration 24, inertia 137940.31176410787
# Iteration 25, inertia 137927.11040726624
# Converged at iteration 25: center shift 0.00027739615106546326 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 159558.7660919829
# Iteration 1, inertia 148400.9883925016
# Iteration 2, inertia 144761.70212014468
# Iteration 3, inertia 143154.63920116535
# Iteration 4, inertia 142426.2276134402
# Iteration 5, inertia 142054.02000029734
# Iteration 6, inertia 141851.23325536394
# Iteration 7, inertia 141732.015981653
# Iteration 8, inertia 141643.87523284042
# Iteration 9, inertia 141576.13764485894
# Iteration 10, inertia 141520.41798708471
# Iteration 11, inertia 141471.30511598813
# Iteration 12, inertia 141430.7068424792
# Iteration 13, inertia 141396.76624337106
# Iteration 14, inertia 141362.17072869273
# Iteration 15, inertia 141328.8630484421
# Iteration 16, inertia 141295.7187731879
# Iteration 17, inertia 141259.79454770335
# Iteration 18, inertia 141223.68405507656
# Iteration 19, inertia 141182.308279011
# Iteration 20, inertia 141131.1828327478
# Iteration 21, inertia 141070.41466615186
# Iteration 22, inertia 140995.37680619152
# Iteration 23, inertia 140904.6218614852
# Iteration 24, inertia 140788.42230995191
# Iteration 25, inertia 140635.40455500476
# Iteration 26, inertia 140460.64620904252
# Iteration 27, inertia 140269.19972838106
# Iteration 28, inertia 140080.42141028657
# Iteration 29, inertia 139909.22196907504
# Iteration 30, inertia 139769.32778596669
# Iteration 31, inertia 139665.11885523063
# Iteration 32, inertia 139595.90198229175
# Iteration 33, inertia 139554.93328273657
# Iteration 34, inertia 139526.55021139357
# Iteration 35, inertia 139503.7807096592
# Iteration 36, inertia 139486.05509265355
# Iteration 37, inertia 139472.24817337096
# Converged at iteration 37: center shift 0.00025704056054563724 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 179155.86546027497
# Iteration 1, inertia 150044.50531204656
# Iteration 2, inertia 145111.57326720178
# Iteration 3, inertia 143276.1216223468
# Iteration 4, inertia 142271.44534816808
# Iteration 5, inertia 141652.2435686896
# Iteration 6, inertia 141243.97061652303
# Iteration 7, inertia 140953.5986087036
# Iteration 8, inertia 140738.46419684135
# Iteration 9, inertia 140553.7463102435
# Iteration 10, inertia 140412.10435795967
# Iteration 11, inertia 140288.1431039109
# Iteration 12, inertia 140166.2426779754
# Iteration 13, inertia 140055.40127266885
# Iteration 14, inertia 139950.97591262942
# Iteration 15, inertia 139853.8761423579
# Iteration 16, inertia 139762.85992754454
# Iteration 17, inertia 139675.36821780296
# Iteration 18, inertia 139581.4952871273
# Iteration 19, inertia 139484.8145761222
# Iteration 20, inertia 139386.95850115846
# Iteration 21, inertia 139287.55013377912
# Iteration 22, inertia 139191.86429834316
# Iteration 23, inertia 139099.5417095745
# Iteration 24, inertia 139009.3860380443
# Iteration 25, inertia 138919.40072494448
# Iteration 26, inertia 138828.13570300065
# Iteration 27, inertia 138733.01130875712
# Iteration 28, inertia 138639.61640631623
# Iteration 29, inertia 138543.8882499992
# Iteration 30, inertia 138455.04430205107
# Iteration 31, inertia 138372.46445345232
# Iteration 32, inertia 138297.10781499272
# Iteration 33, inertia 138231.9414271299
# Iteration 34, inertia 138168.06554344652
# Iteration 35, inertia 138118.1984156557
# Iteration 36, inertia 138074.05519694905
# Iteration 37, inertia 138035.30565070902
# Iteration 38, inertia 138005.99793695562
# Iteration 39, inertia 137978.6476957659
# Iteration 40, inertia 137954.36321642276
# Iteration 41, inertia 137937.2075261718
# Iteration 42, inertia 137923.97237423738
# Converged at iteration 42: center shift 0.000272213612684219 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 164101.4377787488
# Iteration 1, inertia 145168.19994823856
# Iteration 2, inertia 142123.65189222584
# Iteration 3, inertia 140768.90940997415
# Iteration 4, inertia 139969.8366619924
# Iteration 5, inertia 139389.24456188915
# Iteration 6, inertia 138936.08616814512
# Iteration 7, inertia 138589.0850434553
# Iteration 8, inertia 138332.78115554957
# Iteration 9, inertia 138157.55201359323
# Iteration 10, inertia 138043.9864316237
# Iteration 11, inertia 137979.46618151868
# Iteration 12, inertia 137937.23839834932
# Iteration 13, inertia 137908.34928161668
# Iteration 14, inertia 137890.923833805
# Iteration 15, inertia 137880.7997036528
# Converged at iteration 15: center shift 0.00021023233383964026 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 194366.8387643234
# Iteration 1, inertia 156122.42049525812
# Iteration 2, inertia 149470.63450072642
# Iteration 3, inertia 146675.15364743353
# Iteration 4, inertia 145075.74883294516
# Iteration 5, inertia 143968.3897600369
# Iteration 6, inertia 143161.6627922404
# Iteration 7, inertia 142590.32220036848
# Iteration 8, inertia 142186.63917080138
# Iteration 9, inertia 141922.2256621041
# Iteration 10, inertia 141747.1200826466
# Iteration 11, inertia 141630.87204187055
# Iteration 12, inertia 141542.67641463436
# Iteration 13, inertia 141476.2924152473
# Iteration 14, inertia 141424.79495745615
# Iteration 15, inertia 141381.92380525154
# Iteration 16, inertia 141345.21149044833
# Iteration 17, inertia 141308.3149429635
# Iteration 18, inertia 141272.20178234964
# Iteration 19, inertia 141239.19845058286
# Iteration 20, inertia 141201.55544624606
# Iteration 21, inertia 141162.0801588185
# Iteration 22, inertia 141121.99398148892
# Iteration 23, inertia 141076.6537983723
# Iteration 24, inertia 141027.93629194263
# Iteration 25, inertia 140977.7653169356
# Iteration 26, inertia 140923.40623657146
# Iteration 27, inertia 140863.9651329466
# Iteration 28, inertia 140791.29458961196
# Iteration 29, inertia 140693.02537270845
# Iteration 30, inertia 140557.39170244493
# Iteration 31, inertia 140386.49633526808
# Iteration 32, inertia 140157.22141580377
# Iteration 33, inertia 139882.46368065954
# Iteration 34, inertia 139589.557092064
# Iteration 35, inertia 139314.84957428387
# Iteration 36, inertia 139061.81683370407
# Iteration 37, inertia 138815.56421406718
# Iteration 38, inertia 138604.6416292867
# Iteration 39, inertia 138433.20468570443
# Iteration 40, inertia 138297.49744178646
# Iteration 41, inertia 138191.05286066438
# Iteration 42, inertia 138118.67420494667
# Iteration 43, inertia 138062.45843404104
# Iteration 44, inertia 138019.3725494229
# Iteration 45, inertia 137988.35304523085
# Iteration 46, inertia 137962.95379378548
# Iteration 47, inertia 137943.25584439427
# Iteration 48, inertia 137927.52349408861
# Iteration 49, inertia 137915.40862078517
# Iteration 50, inertia 137905.85901552913
# Converged at iteration 50: center shift 0.00026745453881189043 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 187652.06610038452
# Iteration 1, inertia 148697.2995393075
# Iteration 2, inertia 143002.57848663122
# Iteration 3, inertia 141440.38294572866
# Iteration 4, inertia 140788.26251769
# Iteration 5, inertia 140398.46527876134
# Iteration 6, inertia 140097.81085766625
# Iteration 7, inertia 139871.83209400368
# Iteration 8, inertia 139720.58684284828
# Iteration 9, inertia 139625.4857830006
# Iteration 10, inertia 139566.7364041949
# Iteration 11, inertia 139526.11997646053
# Iteration 12, inertia 139498.68223118072
# Iteration 13, inertia 139478.9593795769
# Iteration 14, inertia 139466.24715960067
# Converged at iteration 14: center shift 0.00021933192820084482 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 174619.97186014583
# Iteration 1, inertia 150702.1711942528
# Iteration 2, inertia 144042.3200715763
# Iteration 3, inertia 141408.4445721468
# Iteration 4, inertia 140227.30210942868
# Iteration 5, inertia 139644.98632472823
# Iteration 6, inertia 139314.98567764298
# Iteration 7, inertia 139094.2267707199
# Iteration 8, inertia 138919.23183380545
# Iteration 9, inertia 138771.6736992066
# Iteration 10, inertia 138633.98649534537
# Iteration 11, inertia 138517.50318245115
# Iteration 12, inertia 138415.43536426112
# Iteration 13, inertia 138328.24496908934
# Iteration 14, inertia 138251.60189377668
# Iteration 15, inertia 138181.88827236765
# Iteration 16, inertia 138125.76623098226
# Iteration 17, inertia 138078.3013380235
# Iteration 18, inertia 138037.30468802532
# Iteration 19, inertia 138005.32988341263
# Iteration 20, inertia 137977.46485850378
# Iteration 21, inertia 137952.24962705912
# Iteration 22, inertia 137933.804579342
# Iteration 23, inertia 137920.58610121324
# Converged at iteration 23: center shift 0.0002703978472740005 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 190636.97591546504
# Iteration 1, inertia 164554.5756846876
# Iteration 2, inertia 155590.11923169516
# Iteration 3, inertia 147798.81119272005
# Iteration 4, inertia 143387.90697684378
# Iteration 5, inertia 141811.35851115512
# Iteration 6, inertia 141243.0646667559
# Iteration 7, inertia 140973.00054759628
# Iteration 8, inertia 140774.32494068157
# Iteration 9, inertia 140585.8548036776
# Iteration 10, inertia 140360.8677573548
# Iteration 11, inertia 140101.24049777724
# Iteration 12, inertia 139819.66292105074
# Iteration 13, inertia 139538.5499294537
# Iteration 14, inertia 139278.45687662286
# Iteration 15, inertia 139053.9991383952
# Iteration 16, inertia 138831.5741979295
# Iteration 17, inertia 138639.83838947356
# Iteration 18, inertia 138480.51617404527
# Iteration 19, inertia 138343.28403734596
# Iteration 20, inertia 138232.7846329153
# Iteration 21, inertia 138152.5297087435
# Iteration 22, inertia 138090.65916192648
# Iteration 23, inertia 138042.38438748056
# Iteration 24, inertia 138006.82687061417
# Iteration 25, inertia 137979.03239904065
# Iteration 26, inertia 137956.26750782164
# Iteration 27, inertia 137939.09103399026
# Iteration 28, inertia 137924.4769789968
# Iteration 29, inertia 137913.21500880504
# Converged at iteration 29: center shift 0.00028432377660654373 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 174105.75146636151
# Iteration 1, inertia 146597.47707869834
# Iteration 2, inertia 142902.86857698316
# Iteration 3, inertia 140912.48336670565
# Iteration 4, inertia 139833.97313305148
# Iteration 5, inertia 139223.1269255377
# Iteration 6, inertia 138858.60514385585
# Iteration 7, inertia 138622.76968867416
# Iteration 8, inertia 138458.04767334965
# Iteration 9, inertia 138339.58127080306
# Iteration 10, inertia 138242.76958152268
# Iteration 11, inertia 138165.80758579698
# Iteration 12, inertia 138106.93464236386
# Iteration 13, inertia 138058.7454626338
# Iteration 14, inertia 138019.87974248128
# Iteration 15, inertia 137988.35615616274
# Iteration 16, inertia 137960.10918347933
# Iteration 17, inertia 137938.82038928327
# Iteration 18, inertia 137923.45924587827
# Iteration 19, inertia 137912.22096319616
# Converged at iteration 19: center shift 0.00023161222349545816 within tolerance 0.0002902645639404105.
# Initialization complete
# Iteration 0, inertia 185494.39682500542
# Iteration 1, inertia 150087.81353022775
# Iteration 2, inertia 147459.3767456695
# Iteration 3, inertia 146228.55520648113
# Iteration 4, inertia 145410.27295805572
# Iteration 5, inertia 144774.3537695122
# Iteration 6, inertia 144229.09572842554
# Iteration 7, inertia 143760.48144718865
# Iteration 8, inertia 143383.20851807966
# Iteration 9, inertia 143064.84145503936
# Iteration 10, inertia 142774.94401109265
# Iteration 11, inertia 142510.26998022624
# Iteration 12, inertia 142249.84825552715
# Iteration 13, inertia 142006.65900280746
# Iteration 14, inertia 141793.0827567635
# Iteration 15, inertia 141612.48284222465
# Iteration 16, inertia 141463.52046650287
# Iteration 17, inertia 141325.47171125852
# Iteration 18, inertia 141190.52209679867
# Iteration 19, inertia 141068.57705181278
# Iteration 20, inertia 140951.28140508864
# Iteration 21, inertia 140827.5766834871
# Iteration 22, inertia 140699.27361484937
# Iteration 23, inertia 140563.49199853712
# Iteration 24, inertia 140403.57544637707
# Iteration 25, inertia 140230.68743924017
# Iteration 26, inertia 140063.78019165504
# Iteration 27, inertia 139902.3393334104
# Iteration 28, inertia 139765.36303397335
# Iteration 29, inertia 139659.0190614057
# Iteration 30, inertia 139582.3172414581
# Iteration 31, inertia 139529.5484943739
# Iteration 32, inertia 139492.62518465868
# Iteration 33, inertia 139467.22388293708
# Iteration 34, inertia 139449.5449046577
# Iteration 35, inertia 139436.76834256406
# Converged at iteration 35: center shift 0.00020387445482198858 within tolerance 0.0002902645639404105.
# KMeans(verbose=2)

# %%
spotify_dataKmeans = dataset.copy()
spotify_dataKmeans['cluster_label'] = kmeans.predict(pca_df)

# %%
x = metrics.calinski_harabasz_score(pca_df, spotify_dataKmeans['cluster_label'])
print(x)
# Out:
# 150791.69603218033

# %% [markdown]
# There are 2 major approaches for building recommendation systems — content-based and collaborative filtering.
#
# > Content based: The gist of this approach is that we match users to the content or items they have liked or bought. Here the attributes of the users and the products are important. For example, for movie recommendations, we use features such as director, actors, movie length, genre, etc. to find >similarity between movies.
#
# > Collaborative Filtering: The underlying assumption of the collaborative filtering approach is that if A and B buy similar products, A is more likely to buy a product that B has bought than a product which a random person has bought. Unlike content based, there are no features corresponding to users or items here.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import euclidean_distances
from collections import defaultdict

# %%
features = ['valence', 'year', 'acousticness',
            'danceability', 'duration_ms', 'energy',
            'explicit','instrumentalness', 'key', 
            'liveness', 'loudness', 'mode',
            'popularity','speechiness', 'tempo']

metadata_cols = ['year', 'name',  'artists']

# %%
song_cluster_pipeline = Pipeline([('scaler', StandardScaler()), 
                                  ('kmeans', KMeans(n_clusters=8, 
                                   verbose=2))],verbose=True)
X = dataset[features]
song_cluster_pipeline.fit(X)
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# Initialization complete
# Iteration 0, inertia 2062060.7781208793
# Iteration 1, inertia 1514199.236063819
# Iteration 2, inertia 1456188.0311555099
# Iteration 3, inertia 1430521.0260133548
# Iteration 4, inertia 1415298.8023327566
# Iteration 5, inertia 1406237.3116557216
# Iteration 6, inertia 1402286.7230520255
# Iteration 7, inertia 1400127.089551833
# Iteration 8, inertia 1398790.5259697842
# Iteration 9, inertia 1397814.9929396787
# Iteration 10, inertia 1397001.7923352444
# Iteration 11, inertia 1396262.4447506652
# Iteration 12, inertia 1395512.8487275164
# Iteration 13, inertia 1394616.134199248
# Iteration 14, inertia 1393662.6087383798
# Iteration 15, inertia 1392716.694176499
# Iteration 16, inertia 1391836.6112401923
# Iteration 17, inertia 1391090.2618235885
# Iteration 18, inertia 1390483.7355313157
# Iteration 19, inertia 1389953.5647466485
# Iteration 20, inertia 1389376.4435319374
# Iteration 21, inertia 1388621.597684539
# Iteration 22, inertia 1387563.7679017766
# Iteration 23, inertia 1385968.3869914883
# Iteration 24, inertia 1383698.2222865126
# Iteration 25, inertia 1381221.486626214
# Iteration 26, inertia 1379054.3072231966
# Iteration 27, inertia 1377630.7140431958
# Iteration 28, inertia 1376991.6151578035
# Iteration 29, inertia 1376738.928430324
# Iteration 30, inertia 1376669.5735587715
# Iteration 31, inertia 1376646.379192317
# Iteration 32, inertia 1376640.7765241228
# Converged at iteration 32: center shift 7.118972532073205e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 1992462.7999755421
# Iteration 1, inertia 1512969.0721634114
# Iteration 2, inertia 1473222.8890628794
# Iteration 3, inertia 1457107.6770778117
# Iteration 4, inertia 1447130.475601248
# Iteration 5, inertia 1438236.0700086919
# Iteration 6, inertia 1428108.5379184906
# Iteration 7, inertia 1418643.9912905192
# Iteration 8, inertia 1411425.6059273179
# Iteration 9, inertia 1404957.5771322488
# Iteration 10, inertia 1398251.4277717387
# Iteration 11, inertia 1395069.2839915403
# Iteration 12, inertia 1393761.7451052798
# Iteration 13, inertia 1392895.8776126993
# Iteration 14, inertia 1392316.758636545
# Iteration 15, inertia 1391936.7733770146
# Iteration 16, inertia 1391686.6365672038
# Iteration 17, inertia 1391536.8880470656
# Iteration 18, inertia 1391430.1206651744
# Iteration 19, inertia 1391340.7925461736
# Iteration 20, inertia 1391257.557341305
# Iteration 21, inertia 1391173.190434651
# Iteration 22, inertia 1391095.9203137537
# Iteration 23, inertia 1391022.7898364817
# Iteration 24, inertia 1390949.036571977
# Iteration 25, inertia 1390881.330521971
# Iteration 26, inertia 1390812.5016640816
# Iteration 27, inertia 1390738.347109485
# Iteration 28, inertia 1390666.7958434732
# Iteration 29, inertia 1390585.5022548875
# Iteration 30, inertia 1390501.7882558466
# Iteration 31, inertia 1390397.579286641
# Iteration 32, inertia 1390275.997320632
# Iteration 33, inertia 1390126.3838307424
# Iteration 34, inertia 1389908.9366104386
# Iteration 35, inertia 1389612.732579974
# Iteration 36, inertia 1389173.64677611
# Iteration 37, inertia 1388477.8557975935
# Iteration 38, inertia 1387422.662848873
# Iteration 39, inertia 1385760.873270105
# Iteration 40, inertia 1383467.426311766
# Iteration 41, inertia 1381011.074863634
# Iteration 42, inertia 1378887.4400175395
# Iteration 43, inertia 1377534.4736804059
# Iteration 44, inertia 1376948.0214327206
# Iteration 45, inertia 1376726.7742829418
# Iteration 46, inertia 1376666.4579162975
# Iteration 47, inertia 1376645.7411667192
# Iteration 48, inertia 1376640.661519422
# Converged at iteration 48: center shift 6.685009025109835e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2077140.1931945365
# Iteration 1, inertia 1584038.531340825
# Iteration 2, inertia 1538350.320804252
# Iteration 3, inertia 1505362.1660924256
# Iteration 4, inertia 1472937.3482982244
# Iteration 5, inertia 1432975.2953910227
# Iteration 6, inertia 1424460.361075879
# Iteration 7, inertia 1420652.4493158609
# Iteration 8, inertia 1417285.949125067
# Iteration 9, inertia 1414751.9492727234
# Iteration 10, inertia 1412976.905317892
# Iteration 11, inertia 1411595.4239924124
# Iteration 12, inertia 1410359.3216093997
# Iteration 13, inertia 1408947.5631676205
# Iteration 14, inertia 1406970.002420256
# Iteration 15, inertia 1404490.4846802494
# Iteration 16, inertia 1401353.3123276015
# Iteration 17, inertia 1396673.6054130087
# Iteration 18, inertia 1391168.2422606205
# Iteration 19, inertia 1389882.8699121014
# Iteration 20, inertia 1389447.40624161
# Iteration 21, inertia 1388870.066204463
# Iteration 22, inertia 1388000.6677758414
# Iteration 23, inertia 1386688.7345601362
# Iteration 24, inertia 1384672.1256049457
# Iteration 25, inertia 1382196.0729983503
# Iteration 26, inertia 1379864.3209197773
# Iteration 27, inertia 1378112.9151032895
# Iteration 28, inertia 1377187.0680429884
# Iteration 29, inertia 1376825.7420131825
# Iteration 30, inertia 1376689.1610232545
# Iteration 31, inertia 1376653.416736158
# Iteration 32, inertia 1376642.3895529395
# Iteration 33, inertia 1376639.7648919376
# Converged at iteration 33: center shift 4.047034228769543e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2156424.6971393432
# Iteration 1, inertia 1553172.8100976082
# Iteration 2, inertia 1520020.0421923834
# Iteration 3, inertia 1504997.1340162903
# Iteration 4, inertia 1487038.8960383502
# Iteration 5, inertia 1464789.868272054
# Iteration 6, inertia 1444806.9370183744
# Iteration 7, inertia 1421083.180599768
# Iteration 8, inertia 1392001.9378782767
# Iteration 9, inertia 1389103.252424873
# Iteration 10, inertia 1388149.2209419557
# Iteration 11, inertia 1387536.1705250908
# Iteration 12, inertia 1387145.8228626302
# Iteration 13, inertia 1386898.0251152273
# Iteration 14, inertia 1386734.5217215044
# Iteration 15, inertia 1386630.0142680765
# Iteration 16, inertia 1386562.5543503566
# Iteration 17, inertia 1386518.5614357763
# Iteration 18, inertia 1386496.1501438795
# Iteration 19, inertia 1386482.1899795886
# Iteration 20, inertia 1386471.9442794528
# Iteration 21, inertia 1386465.617334567
# Converged at iteration 21: center shift 6.399409009866358e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 1911562.5786964074
# Iteration 1, inertia 1479777.5537371775
# Iteration 2, inertia 1451421.1844355797
# Iteration 3, inertia 1438413.3550260346
# Iteration 4, inertia 1426916.9706242466
# Iteration 5, inertia 1415371.4251643778
# Iteration 6, inertia 1405132.0049797248
# Iteration 7, inertia 1398172.6416368184
# Iteration 8, inertia 1394547.8829960646
# Iteration 9, inertia 1392744.1424834784
# Iteration 10, inertia 1391663.9189741528
# Iteration 11, inertia 1390928.199925301
# Iteration 12, inertia 1390398.6437619152
# Iteration 13, inertia 1389950.493175555
# Iteration 14, inertia 1389498.483768383
# Iteration 15, inertia 1388993.4893857376
# Iteration 16, inertia 1388476.3027227349
# Iteration 17, inertia 1387956.4019024079
# Iteration 18, inertia 1387514.1534239845
# Iteration 19, inertia 1387163.7703309492
# Iteration 20, inertia 1386911.4969351164
# Iteration 21, inertia 1386723.8356021005
# Iteration 22, inertia 1386607.256859766
# Iteration 23, inertia 1386542.5559513038
# Iteration 24, inertia 1386503.2859099163
# Iteration 25, inertia 1386484.0995091954
# Iteration 26, inertia 1386474.3743676513
# Iteration 27, inertia 1386468.7439310057
# Converged at iteration 27: center shift 8.345390747022135e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2111452.407295093
# Iteration 1, inertia 1574542.4264458818
# Iteration 2, inertia 1535807.484661524
# Iteration 3, inertia 1507343.5624215235
# Iteration 4, inertia 1472117.1911944812
# Iteration 5, inertia 1433094.7123472118
# Iteration 6, inertia 1406699.015257509
# Iteration 7, inertia 1404465.3495408292
# Iteration 8, inertia 1403033.4448929555
# Iteration 9, inertia 1401813.6971310573
# Iteration 10, inertia 1400836.2696437729
# Iteration 11, inertia 1400076.4379669172
# Iteration 12, inertia 1399525.567989754
# Iteration 13, inertia 1399095.768666588
# Iteration 14, inertia 1398764.1986914696
# Iteration 15, inertia 1398487.1786060082
# Iteration 16, inertia 1398255.5849932537
# Iteration 17, inertia 1398023.9339338636
# Iteration 18, inertia 1397777.48106245
# Iteration 19, inertia 1397507.98746541
# Iteration 20, inertia 1397192.7012989274
# Iteration 21, inertia 1396803.3851953463
# Iteration 22, inertia 1396300.447550086
# Iteration 23, inertia 1395651.470638094
# Iteration 24, inertia 1394876.9239695221
# Iteration 25, inertia 1394067.6225390849
# Iteration 26, inertia 1393298.4210907854
# Iteration 27, inertia 1392701.8687446122
# Iteration 28, inertia 1392323.7122603166
# Iteration 29, inertia 1392089.033037938
# Iteration 30, inertia 1391951.5827543172
# Iteration 31, inertia 1391877.9505811976
# Iteration 32, inertia 1391840.9762775092
# Iteration 33, inertia 1391823.618729347
# Iteration 34, inertia 1391815.88749898
# Iteration 35, inertia 1391811.7245362855
# Converged at iteration 35: center shift 8.428312809502457e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2009046.6414390241
# Iteration 1, inertia 1581290.3962728274
# Iteration 2, inertia 1545596.9019570076
# Iteration 3, inertia 1524971.431612368
# Iteration 4, inertia 1512629.904485505
# Iteration 5, inertia 1502957.516683024
# Iteration 6, inertia 1496534.7746746782
# Iteration 7, inertia 1491447.128771552
# Iteration 8, inertia 1486250.3248886745
# Iteration 9, inertia 1480911.4293632868
# Iteration 10, inertia 1476413.978222006
# Iteration 11, inertia 1473202.7163999751
# Iteration 12, inertia 1471756.039274558
# Iteration 13, inertia 1471228.3739169058
# Iteration 14, inertia 1471030.8512753611
# Iteration 15, inertia 1470945.0852140186
# Iteration 16, inertia 1470908.1404137667
# Iteration 17, inertia 1470891.552448985
# Iteration 18, inertia 1470883.0193544193
# Iteration 19, inertia 1470878.2633499291
# Converged at iteration 19: center shift 6.706575393982781e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2075827.8738204124
# Iteration 1, inertia 1531219.7004893934
# Iteration 2, inertia 1495059.865312848
# Iteration 3, inertia 1480935.5730573763
# Iteration 4, inertia 1471649.1115119657
# Iteration 5, inertia 1458547.1589321562
# Iteration 6, inertia 1428431.2904124265
# Iteration 7, inertia 1401844.9008026256
# Iteration 8, inertia 1399386.6219767914
# Iteration 9, inertia 1397576.6135386163
# Iteration 10, inertia 1395960.4308781927
# Iteration 11, inertia 1394499.1042613294
# Iteration 12, inertia 1393336.3915184522
# Iteration 13, inertia 1392358.8214629593
# Iteration 14, inertia 1391502.5478405058
# Iteration 15, inertia 1390696.9599278877
# Iteration 16, inertia 1389869.369499569
# Iteration 17, inertia 1389076.242424273
# Iteration 18, inertia 1388307.1012814476
# Iteration 19, inertia 1387680.3199136541
# Iteration 20, inertia 1387218.9407231696
# Iteration 21, inertia 1386901.177777307
# Iteration 22, inertia 1386719.070029771
# Iteration 23, inertia 1386616.7220288445
# Iteration 24, inertia 1386553.3808856928
# Iteration 25, inertia 1386512.0341306448
# Iteration 26, inertia 1386488.2501511504
# Iteration 27, inertia 1386475.481000657
# Iteration 28, inertia 1386468.8519014993
# Converged at iteration 28: center shift 7.755348572340028e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2131880.206553027
# Iteration 1, inertia 1588403.0296263127
# Iteration 2, inertia 1547918.539894876
# Iteration 3, inertia 1530799.589608978
# Iteration 4, inertia 1517835.020449737
# Iteration 5, inertia 1503293.9716045929
# Iteration 6, inertia 1495602.3563434356
# Iteration 7, inertia 1492183.88844983
# Iteration 8, inertia 1489799.4928972845
# Iteration 9, inertia 1486537.7813268285
# Iteration 10, inertia 1480532.135000883
# Iteration 11, inertia 1471345.3207894517
# Iteration 12, inertia 1461729.323781202
# Iteration 13, inertia 1446397.0128372132
# Iteration 14, inertia 1412321.2469538678
# Iteration 15, inertia 1392172.261179784
# Iteration 16, inertia 1390152.325419784
# Iteration 17, inertia 1388942.936700733
# Iteration 18, inertia 1388163.5677148928
# Iteration 19, inertia 1387664.0843958082
# Iteration 20, inertia 1387316.766821942
# Iteration 21, inertia 1387063.3312294227
# Iteration 22, inertia 1386885.2816481967
# Iteration 23, inertia 1386750.5823583477
# Iteration 24, inertia 1386647.3528113454
# Iteration 25, inertia 1386578.2435928988
# Iteration 26, inertia 1386537.0246084407
# Iteration 27, inertia 1386511.9368884778
# Iteration 28, inertia 1386493.9585404117
# Iteration 29, inertia 1386482.1151327463
# Iteration 30, inertia 1386474.1576215974
# Converged at iteration 30: center shift 8.224974678733806e-05 within tolerance 0.00010000000000000789.
# Initialization complete
# Iteration 0, inertia 2109153.3805749984
# Iteration 1, inertia 1563496.915811391
# Iteration 2, inertia 1533844.1438475992
# Iteration 3, inertia 1511808.457529239
# Iteration 4, inertia 1494839.253224653
# Iteration 5, inertia 1479864.3966350267
# Iteration 6, inertia 1470902.8592906166
# Iteration 7, inertia 1465525.272354465
# Iteration 8, inertia 1461469.1921483055
# Iteration 9, inertia 1454097.7443887652
# Iteration 10, inertia 1433217.0874904324
# Iteration 11, inertia 1409636.8469507797
# Iteration 12, inertia 1408730.7589954387
# Iteration 13, inertia 1408555.2796411118
# Iteration 14, inertia 1408473.9674370023
# Iteration 15, inertia 1408429.7293844523
# Iteration 16, inertia 1408405.9982002499
# Iteration 17, inertia 1408393.3713733642
# Iteration 18, inertia 1408384.4559062885
# Converged at iteration 18: center shift 9.158163241977385e-05 within tolerance 0.00010000000000000789.
# [Pipeline] ............ (step 2 of 2) Processing kmeans, total=   8.6s
# Pipeline(steps=[('scaler', StandardScaler()), ('kmeans', KMeans(verbose=2))],
#          verbose=True)

# %% [markdown]
# ## Generating song recommendations
# Now we can finally build the music recommendation system!
#
# This algorithm follows a common approach that is used in content-based recommender systems and is generalizable because we can mathematically define the term closest with a wide range of distance metrics ranging from the classic Euclidean distance to the cosine distance. For the purpose of this project, I used the cosine distance, which is defined below for two vectors u and v.
#
# Cosine distance formula.
# In other words, the cosine distance is one minus the cosine similarity — the cosine of the angle between the two vectors. The cosine distance is commonly used in recommender systems and can work well even when the vectors being used have different magnitudes. If the vectors for two songs are parallel, the angle between them will be zero, meaning the cosine distance between them will also be zero because the cosine of zero is 1.
#
# Scipy’s cdist function is used for finding the distances between two pairs of collections of points.

# %%
from spotipy.oauth2 import SpotifyClientCredentials
from collections import defaultdict

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="c996320d9deb4688a62220b0cf198c86", 
                                                           client_secret="d1b45bcd2e434cbf9e538f1b5a882cf9"))


def find_song(name, year):
  
    """
    This function returns a dataframe with data for a song given the name and release year.
    The function uses Spotipy to fetch audio features and metadata for the specified song.
    
    """
    
    song_data = defaultdict()
    results = sp.search(q= 'track: {} year: {}'.format(name,
                                                       year), limit=1)
    if results['tracks']['items'] == []:
        return None
    
    results = results['tracks']['items'][0]

    track_id = results['id']
    audio_features = sp.audio_features(track_id)[0]
    
    song_data['name'] = [name]
    song_data['year'] = [year]
    song_data['explicit'] = [int(results['explicit'])]
    song_data['duration_ms'] = [results['duration_ms']]
    song_data['popularity'] = [results['popularity']]
    
    for key, value in audio_features.items():
        song_data[key] = value
    
    return pd.DataFrame(song_data)

# %%
from collections import defaultdict
from scipy.spatial.distance import cdist
import difflib

number_cols = ['valence', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity', 'speechiness', 'tempo']

def get_song_data(song, spotify_data):
    
    """
    Gets the song data for a specific song. The song argument takes the form of a dictionary with 
    key-value pairs for the name and release year of the song.
    """
    
    try:
        song_data = spotify_data[(spotify_data['name'] == song['name']) 
                                & (spotify_data['year'] == song['year'])].iloc[0]
        return song_data
    
    except IndexError:
        return find_song(song['name'], song['year'])
        

def get_mean_vector(song_list, spotify_data):
  
    """
    Gets the mean vector for a list of songs.
    """
    
    song_vectors = []
    
    for song in song_list:
        song_data = get_song_data(song, spotify_data)
        if song_data is None:
            print('Warning: {} does not exist in Spotify or in database'.format(song['name']))
            continue
        song_vector = song_data[number_cols].values
        song_vectors.append(song_vector)  
    
    song_matrix = np.array(list(song_vectors))
    return np.mean(song_matrix, axis=0)

def flatten_dict_list(dict_list):
   
    """
    Utility function for flattening a list of dictionaries.
    """
    
    flattened_dict = defaultdict()
    for key in dict_list[0].keys():
        flattened_dict[key] = []
    
    for dictionary in dict_list:
        for key, value in dictionary.items():
            flattened_dict[key].append(value)
            
    return flattened_dict

# %%
def recommend_songs(song_list, spotify_data, n_songs=10):
  
    """
    Recommends songs based on a list of previous songs that a user has listened to.
    """
    
    metadata_cols = ['name', 'year', 'artists']
    song_dict = flatten_dict_list(song_list)
    
    song_center = get_mean_vector(song_list, spotify_data)
    scaler = song_cluster_pipeline.steps[0][1]
    scaled_data = scaler.transform(spotify_data[number_cols])
    scaled_song_center = scaler.transform(song_center.reshape(1, -1))
    distances = cdist(scaled_song_center, scaled_data, 'cosine')
    index = list(np.argsort(distances)[:, :n_songs][0])
    
    rec_songs = spotify_data.iloc[index]
    rec_songs = rec_songs[~rec_songs['name'].isin(song_dict['name'])]
    return rec_songs[metadata_cols].to_dict(orient='records')

# %%
results = recommend_songs([{'name': 'Toosie Slide', 'year': 2020},
                                          {'name': 'Outta Time (feat. Drake)', 'year': 2020},
                                          {'name': 'Chicago Freestyle (feat. Giveon)', 'year': 2020}],dataset)
results
# Out:
# [{'artists': "['Doja Cat', 'Gucci Mane']",
#   'name': 'Like That (feat. Gucci Mane)',
#   'year': 2019},
#  {'artists': "['Rod Wave', 'Lil Baby']",
#   'name': 'Rags2Riches 2 (feat. Lil Baby)',
#   'year': 2020},
#  {'artists': "['Pop Smoke', 'Lil Baby', 'DaBaby']",
#   'name': 'For The Night (feat. Lil Baby & DaBaby)',
#   'year': 2020},
#  {'artists': "['Kodak Black', 'Offset', 'Travis Scott']",
#   'name': 'ZEZE (feat. Travis Scott & Offset)',
#   'year': 2018},
#  {'artists': "['A$AP Rocky', 'Skepta']",
#   'name': 'Praise The Lord (Da Shine) (feat. Skepta)',
#   'year': 2018},
#  {'artists': "['Jhay Cortez', 'Bad Bunny']",
#   'name': 'CÓMO SE SIENTE - Remix',
#   'year': 2020},
#  {'artists': "['Joseph Black']", 'name': '(i hope you) miss me', 'year': 2020},
#  {'artists': "['Young Thug', 'J. Cole', 'Travis Scott']",
#   'name': 'The London (feat. J. Cole & Travis Scott)',
#   'year': 2019},
#  {'artists': "['$NOT', 'Wifisfuneral']",
#   'name': 'BERETTA (feat. Wifisfuneral)',
#   'year': 2020},
#  {'artists': "['Sueco']", 'name': 'fast', 'year': 2019}]
